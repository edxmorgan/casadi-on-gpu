# %% [markdown]
# # Generate FK CUDA code (local output)
#
# This notebook generates CUDA-ready CasADi code directly into `src/generated/` using the new `cuda` CodeGenerator option.

# %%
import casadi as ca
print("CasADi from:", ca.__file__)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 7
#       4 sys.path.insert(0, "/tmp/casadi-local")
#       6 # Ensure the local libcasadi is visible to the loader
# ----> 7 ctypes.CDLL("/tmp/casadi-build/lib/libcasadi.so", mode=ctypes.RTLD_GLOBAL)
#       9 import casadi as ca
#      10 print("CasADi from:", ca.__file__)
#
# File /usr/lib/python3.12/ctypes/__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     376 self._FuncPtr = _FuncPtr
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#     381     self._handle = handle
#
# OSError: /tmp/casadi-build/lib/libcasadi.so: cannot open shared object file: No such file or directory

# %%
from pathlib import Path

fk_eval = ca.Function.load("fk_eval.casadi")

# %%
base_dir = Path.cwd().parent
codegen_folder = base_dir / "src" / "generated"
codegen_folder.mkdir(exist_ok=True, parents=True)

fname = fk_eval.name()
cg = ca.CodeGenerator("fk_alpha", {
    "with_header": True,
    "casadi_real": "float",
    "cpp": False,
    "cuda": True,
    "cuda_kernels": {
        fname: {
            "batch_inputs": [0],
        }
    },
})
cg.add(fk_eval)
out_path = cg.generate(str(codegen_folder) + "/")
out_path
# Out:
# '/home/mr-robot/sci_ws/casadi-on-gpu/src/generated/fk_alpha.cu'

# %%
(codegen_folder / "fk_alpha.cu").exists(), (codegen_folder / "fk_alpha.cuh").exists()
# Out:
# (True, True)
